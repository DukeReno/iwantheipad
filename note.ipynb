# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from unicodedata import normalize
import requests

# %%
df = pd.read_html('https://en.m.wikipedia.org/wiki/List_of_Nobel_laureates')[0]
print(f'Total tables: {len(df)}')
print(type(df))
df.columns
# Out:
# Total tables: 124
# <class 'pandas.core.frame.DataFrame'>
# Index(['Year', 'Physics', 'Chemistry', 'Physiology or Medicine', 'Literature',
#        'Peace', 'Economics (The Sveriges Riksbank Prize)[13][a]'],
#       dtype='object')

# %%
df.drop(df.tail(1).index, inplace=True)

# %%
dict = { 'Physics':[], 'Chemistry':[], 'Physiology or Medicine':[], 'Literature':[],
       'Peace':[], 'Economics (The Sveriges Riksbank Prize)[13][a]':[]
}

# %%
print(type(df))
for (id, row) in df["Physics"].items():
    for name in str(row).split("; "):
        dict["Physics"].append(name)

for (id, row) in df["Chemistry"].items():
    for name in str(row).split("; "):
        dict["Chemistry"].append(name)

for (id, row) in df["Physiology or Medicine"].items():
    for name in str(row).split("; "):
        dict["Physiology or Medicine"].append(name)

for (id, row) in df["Literature"].items():
    for name in str(row).split("; "):
        dict["Literature"].append(name)

for (id, row) in df["Peace"].items():
    for name in str(row).split("; "):
        dict["Peace"].append(name)
        
for (id, row) in df["Economics (The Sveriges Riksbank Prize)[13][a]"].items():
    for name in str(row).split("; "):
        dict["Economics (The Sveriges Riksbank Prize)[13][a]"].append(name)
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
#print(len(dict["Physics"]))
print(dict["Physics"])
# Out:
# ['Wilhelm Röntgen', 'Hendrik Lorentz', 'Pieter Zeeman', 'Henri Becquerel', 'Pierre Curie', 'Marie Curie', 'Lord Rayleigh', 'Philipp Lenard', 'J. J. Thomson', 'Albert A. Michelson', 'Gabriel Lippmann', 'Karl Ferdinand Braun', 'Guglielmo Marconi', 'Johannes Diderik van der Waals', 'Wilhelm Wien', 'Gustaf Dalén', 'Heike Kamerlingh Onnes', 'Max von Laue', 'William Henry Bragg', 'Lawrence Bragg', 'nan', 'Charles Glover Barkla', 'Max Planck', 'Johannes Stark', 'Charles Édouard Guillaume', 'Albert Einstein', 'Niels Bohr', 'Robert Andrews Millikan', 'Manne Siegbahn', 'James Franck', 'Gustav Ludwig Hertz', 'Jean Baptiste Perrin', 'Arthur Compton', 'Charles Thomson Rees Wilson', 'Owen Willans Richardson', 'Louis de Broglie', 'C. V. Raman', 'nan', 'Werner Heisenberg', 'Erwin Schrödinger', 'Paul Dirac', 'nan', 'James Chadwick', 'Victor Francis Hess', 'Carl David Anderson', 'Clinton Davisson', 'George Paget Thomson', 'Enrico Fermi', 'Ernest Lawrence', 'Cancelled due to World War II', 'Cancelled due to World War II', 'Cancelled due to World War II', 'Otto Stern', 'Isidor Isaac Rabi', 'Wolfgang Pauli', 'Percy Williams Bridgman', 'Edward Victor Appleton', 'Patrick Blackett', 'Hideki Yukawa', 'C. F. Powell', 'John Cockcroft', 'Ernest Walton', 'Felix Bloch', 'Edward Mills Purcell', 'Frits Zernike', 'Max Born', 'Walther Bothe', 'Willis Lamb', 'Polykarp Kusch', 'John Bardeen', 'Walter Houser Brattain', 'William Shockley', 'Yang Chen-Ning', 'Tsung-Dao Lee', 'Pavel Cherenkov', 'Ilya Frank', 'Igor Tamm', 'Emilio Segrè', 'Owen Chamberlain', 'Donald A. Glaser', 'Robert Hofstadter', 'Rudolf Mössbauer', 'Lev Landau', 'Eugene Wigner', 'Maria Goeppert Mayer', 'J. Hans D. Jensen', 'Charles H. Townes', 'Nikolay Basov', 'Alexander Prokhorov', "Shin'ichirō Tomonaga", 'Julian Schwinger', 'Richard Feynman', 'Alfred Kastler', 'Hans Bethe', 'Luis Walter Alvarez', 'Murray Gell-Mann', 'Hannes Alfvén', 'Louis Néel', 'Dennis Gabor', 'John Bardeen', 'Leon Cooper', 'John Robert Schrieffer', 'Leo Esaki', 'Ivar Giaever', 'Brian Josephson', 'Martin Ryle', 'Antony Hewish', 'Aage Bohr', 'Ben Roy Mottelson', 'James Rainwater', 'Burton Richter', 'Samuel C. C. Ting', 'Philip W. Anderson', 'Nevill Francis Mott', 'John Hasbrouck Van Vleck', 'Pyotr Kapitsa', 'Arno Allan Penzias', 'Robert Woodrow Wilson', 'Sheldon Glashow', 'Abdus Salam', 'Steven Weinberg', 'James Cronin', 'Val Logsdon Fitch', 'Nicolaas Bloembergen', 'Arthur Leonard Schawlow', 'Kai Siegbahn', 'Kenneth G. Wilson', 'Subrahmanyan Chandrasekhar', 'William Alfred Fowler', 'Carlo Rubbia', 'Simon van der Meer', 'Klaus von Klitzing', 'Ernst Ruska', 'Gerd Binnig', 'Heinrich Rohrer', 'Georg Bednorz', 'K. Alex Müller', 'Leon M. Lederman', 'Melvin Schwartz', 'Jack Steinberger', 'Norman Ramsey Jr.', 'Hans Georg Dehmelt', 'Wolfgang Paul', 'Jerome Isaac Friedman', 'Henry Way Kendall', 'Richard E. Taylor', 'Pierre-Gilles de Gennes', 'Georges Charpak', 'Russell Alan Hulse', 'Joseph Hooton Taylor Jr.', 'Bertram Brockhouse', 'Clifford Shull', 'Martin Lewis Perl', 'Frederick Reines', 'David Lee', 'Douglas Osheroff', 'Robert Coleman Richardson', 'Steven Chu', 'Claude Cohen-Tannoudji', 'William Daniel Phillips', 'Robert B. Laughlin', 'Horst Ludwig Störmer', 'Daniel C. Tsui', "Gerard 't Hooft", 'Martinus J. G. Veltman', 'Jack Kilby', 'Zhores Alferov', 'Herbert Kroemer', 'Eric Allin Cornell', 'Wolfgang Ketterle', 'Carl Wieman', 'Riccardo Giacconi', 'Raymond Davis Jr.', 'Masatoshi Koshiba', 'Alexei Abrikosov', 'Vitaly Ginzburg', 'Anthony James Leggett', 'David Gross', 'Hugh David Politzer', 'Frank Wilczek', 'Roy J. Glauber', 'John L. Hall', 'Theodor W. Hänsch', 'John C. Mather', 'George Smoot', 'Albert Fert', 'Peter Grünberg', 'Yoichiro Nambu', 'Makoto Kobayashi', 'Toshihide Maskawa', 'Charles K. Kao', 'Willard S. Boyle', 'George E. Smith', 'Andre Geim', 'Konstantin Novoselov', 'Saul Perlmutter', 'Adam Riess', 'Brian Schmidt', 'Serge Haroche', 'David J. Wineland', 'François Englert', 'Peter W. Higgs', 'Isamu Akasaki', 'Hiroshi Amano', 'Sh ...

# %%
print(dict["Chemistry"])
# Out:
# ["Jacobus Henricus van 't Hoff", 'Emil Fischer', 'Svante Arrhenius', 'William Ramsay', 'Adolf von Baeyer', 'Henri Moissan', 'Eduard Buchner', 'Ernest Rutherford', 'Wilhelm Ostwald', 'Otto Wallach', 'Marie Curie', 'Victor Grignard', 'Paul Sabatier', 'Alfred Werner', 'Theodore William Richards', 'Richard Willstätter', 'nan', 'nan', 'Fritz Haber', 'nan', 'Walther Nernst', 'Frederick Soddy', 'Francis William Aston', 'Fritz Pregl', 'nan', 'Richard Adolf Zsigmondy', 'Theodor Svedberg', 'Heinrich Otto Wieland', 'Adolf Windaus', 'Arthur Harden', 'Hans von Euler-Chelpin', 'Hans Fischer', 'Carl Bosch', 'Friedrich Bergius', 'Irving Langmuir', 'nan', 'Harold Urey', 'Frédéric Joliot-Curie', 'Irène Joliot-Curie', 'Peter Debye', 'Norman Haworth', 'Paul Karrer', 'Richard Kuhn[b]', 'Adolf Butenandt;[b] Leopold Ružička', 'Cancelled due to World War II', 'Cancelled due to World War II', 'Cancelled due to World War II', 'George de Hevesy', 'Otto Hahn', 'Artturi Ilmari Virtanen', 'James B. Sumner', 'John Howard Northrop', 'Wendell Meredith Stanley', 'Robert Robinson', 'Arne Tiselius', 'William Giauque', 'Otto Diels', 'Kurt Alder', 'Edwin McMillan', 'Glenn T. Seaborg', 'Archer Martin', 'Richard Laurence Millington Synge', 'Hermann Staudinger', 'Linus Pauling', 'Vincent du Vigneaud', 'Cyril Norman Hinshelwood', 'Nikolay Semyonov', 'The Lord Todd', 'Frederick Sanger', 'Jaroslav Heyrovský', 'Willard Libby', 'Melvin Calvin', 'Max Perutz', 'John Kendrew', 'Karl Ziegler', 'Giulio Natta', 'Dorothy Hodgkin', 'Robert Burns Woodward', 'Robert S. Mulliken', 'Manfred Eigen', 'Ronald George Wreyford Norrish', 'George Porter', 'Lars Onsager', 'Derek Barton', 'Odd Hassel', 'Luis Federico Leloir', 'Gerhard Herzberg', 'Christian B. Anfinsen', 'Stanford Moore', 'William Howard Stein', 'Ernst Otto Fischer', 'Geoffrey Wilkinson', 'Paul Flory', 'John Cornforth', 'Vladimir Prelog', 'William Lipscomb', 'Ilya Prigogine', 'Peter D. Mitchell', 'Herbert C. Brown', 'Georg Wittig', 'Paul Berg', 'Walter Gilbert', 'Frederick Sanger', 'Kenichi Fukui', 'Roald Hoffmann', 'Aaron Klug', 'Henry Taube', 'Robert Bruce Merrifield', 'Herbert A. Hauptman', 'Jerome Karle', 'Dudley R. Herschbach', 'Yuan T. Lee', 'John Polanyi', 'Donald J. Cram', 'Jean-Marie Lehn', 'Charles J. Pedersen', 'Johann Deisenhofer', 'Robert Huber', 'Hartmut Michel', 'Sidney Altman', 'Thomas Cech', 'Elias James Corey', 'Richard R. Ernst', 'Rudolph A. Marcus', 'Kary Mullis', 'Michael Smith', 'George Andrew Olah', 'Paul J. Crutzen', 'Mario J. Molina', 'F. Sherwood Rowland', 'Robert Curl', 'Harry Kroto', 'Richard Smalley', 'Paul D. Boyer', 'John E. Walker', 'Jens Christian Skou', 'Walter Kohn', 'John Pople', 'Ahmed Zewail', 'Alan J. Heeger', 'Alan MacDiarmid', 'Hideki Shirakawa', 'William Standish Knowles', 'Ryōji Noyori', 'Karl Barry Sharpless', 'John B. Fenn', 'Koichi Tanaka', 'Kurt Wüthrich', 'Peter Agre', 'Roderick MacKinnon', 'Aaron Ciechanover', 'Avram Hershko', 'Irwin Rose', 'Yves Chauvin', 'Robert H. Grubbs', 'Richard R. Schrock', 'Roger D. Kornberg', 'Gerhard Ertl', 'Osamu Shimomura', 'Martin Chalfie', 'Roger Y. Tsien', 'Venkatraman Ramakrishnan', 'Thomas A. Steitz', 'Ada Yonath', 'Richard F. Heck', 'Ei-ichi Negishi', 'Akira Suzuki', 'Dan Shechtman', 'Brian K. Kobilka', 'Robert J. Lefkowitz', 'Martin Karplus', 'Michael Levitt', 'Arieh Warshel', 'Eric Betzig', 'Stefan Hell', 'William Moerner', 'Tomas Lindahl', 'Paul L. Modrich', 'Aziz Sancar', 'Jean-Pierre Sauvage', 'Fraser Stoddart', 'Ben Feringa', 'Jacques Dubochet', 'Joachim Frank', 'Richard Henderson', 'Frances H. Arnold', 'George Smith', 'Greg Winter', 'John B. Goodenough', 'M. Stanley Whittingham', 'Akira Yoshino', 'Emmanuelle Charpentier', 'Jennifer Doudna', 'Benjamin List', 'David MacMillan', 'Carolyn Bertozzi', 'Morten P. Meldal', 'Karl Barry Sharpless', 'Moungi Bawendi', 'Louis E. Brus', 'Alexey Ekimov']

# %%
print(dict["Economics (The Sveriges Riksbank Prize)[13][a]"])
# Out:
# ['—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', '—', 'Ragnar Frisch', 'Jan Tinbergen', 'Paul Samuelson', 'Simon Kuznets', 'John Hicks', 'Kenneth Arrow', 'Wassily Leontief', 'Gunnar Myrdal', 'Friedrich Hayek', 'Leonid Kantorovich', 'Tjalling Koopmans', 'Milton Friedman', 'Bertil Ohlin', 'James Meade', 'Herbert A. Simon', 'Theodore Schultz', 'W. Arthur Lewis', 'Lawrence Klein', 'James Tobin', 'George Stigler', 'Gérard Debreu', 'Richard Stone', 'Franco Modigliani', 'James M. Buchanan', 'Robert Solow', 'Maurice Allais', 'Trygve Haavelmo', 'Harry Markowitz', 'Merton Miller', 'William F. Sharpe', 'Ronald Coase', 'Gary Becker', 'Robert Fogel', 'Douglass North', 'John Harsanyi', 'John Forbes Nash Jr.', 'Reinhard Selten', 'Robert Lucas Jr.', 'James Mirrlees', 'William Vickrey', 'Robert C. Merton', 'Myron Scholes', 'Amartya Sen', 'Robert Mundell', 'James Heckman', 'Daniel McFadden', 'George Akerlof', 'Michael Spence', 'Joseph Stiglitz', 'Daniel Kahneman', 'Vernon L. Smith', 'Robert F. Engle', 'Clive Granger', 'Finn E. Kydland', 'Edward C. Prescott', 'Robert Aumann', 'Thomas Schelling', 'Edmund Phelps', 'Leonid Hurwicz', 'Eric Maskin', 'Roger Myerson', 'Paul Krugman', 'Elinor Ostrom', 'Oliver E. Williamson', 'Peter A. Diamond', 'Dale T. Mortensen', 'Christopher A. Pissarides', 'Thomas J. Sargent', 'Christopher A. Sims', 'Alvin E. Roth', 'Lloyd S. Shapley', 'Eugene F. Fama', 'Lars Peter Hansen', 'Robert J. Shiller', 'Jean Tirole', 'Angus Deaton', 'Oliver Hart', 'Bengt R. Holmström', 'Richard Thaler', 'William Nordhaus', 'Paul Romer', 'Abhijit Banerjee', 'Esther Duflo', 'Michael Kremer', 'Paul Milgrom', 'Robert B. Wilson', 'David Card', 'Joshua Angrist', 'Guido Imbens', 'Ben Bernanke', 'Douglas Diamond', 'Philip H. Dybvig', 'Claudia Goldin']

# %%
print(dict["Literature"])
# Out:
# ['Sully Prudhomme', 'Theodor Mommsen', 'Bjørnstjerne Bjørnson', 'Frédéric Mistral', 'José Echegaray', 'Henryk Sienkiewicz', 'Giosuè Carducci', 'Rudyard Kipling', 'Rudolf Christoph Eucken', 'Selma Lagerlöf', 'Paul Heyse', 'Maurice Maeterlinck', 'Gerhart Hauptmann', 'Rabindranath Tagore', 'nan', 'Romain Rolland', 'Verner von Heidenstam', 'Karl Adolph Gjellerup', 'Henrik Pontoppidan', 'nan', 'Carl Spitteler', 'Knut Hamsun', 'Anatole France', 'Jacinto Benavente', 'W. B. Yeats', 'Władysław Reymont', 'George Bernard Shaw', 'Grazia Deledda', 'Henri Bergson', 'Sigrid Undset', 'Thomas Mann', 'Sinclair Lewis', 'Erik Axel Karlfeldt', 'John Galsworthy', 'Ivan Bunin', 'Luigi Pirandello', 'nan', "Eugene O'Neill", 'Roger Martin du Gard', 'Pearl S. Buck', 'Frans Eemil Sillanpää', 'Cancelled due to World War II', 'Cancelled due to World War II', 'Cancelled due to World War II', 'nan', 'Johannes V. Jensen', 'Gabriela Mistral', 'Hermann Hesse', 'André Gide', 'T. S. Eliot', 'William Faulkner', 'Bertrand Russell', 'Pär Lagerkvist', 'François Mauriac', 'Winston Churchill', 'Ernest Hemingway', 'Halldór Laxness', 'Juan Ramón Jiménez', 'Albert Camus', 'Boris Pasternak[d]', 'Salvatore Quasimodo', 'Saint-John Perse', 'Ivo Andrić', 'John Steinbeck', 'Giorgos Seferis', 'Jean-Paul Sartre[e]', 'Mikhail Sholokhov', 'Shmuel Yosef Agnon', 'Nelly Sachs', 'Miguel Ángel Asturias', 'Yasunari Kawabata', 'Samuel Beckett', 'Aleksandr Solzhenitsyn', 'Pablo Neruda', 'Heinrich Böll', 'Patrick White', 'Eyvind Johnson', 'Harry Martinson', 'Eugenio Montale', 'Saul Bellow', 'Vicente Aleixandre', 'Isaac Bashevis Singer', 'Odysseas Elytis', 'Czesław Miłosz', 'Elias Canetti', 'Gabriel García Márquez', 'William Golding', 'Jaroslav Seifert', 'Claude Simon', 'Wole Soyinka', 'Joseph Brodsky', 'Naguib Mahfouz', 'Camilo José Cela', 'Octavio Paz', 'Nadine Gordimer', 'Derek Walcott', 'Toni Morrison', 'Kenzaburō Ōe', 'Seamus Heaney', 'Wisława Szymborska', 'Dario Fo', 'José Saramago', 'Günter Grass', 'Gao Xingjian', 'V. S. Naipaul', 'Imre Kertész', 'J. M. Coetzee', 'Elfriede Jelinek', 'Harold Pinter', 'Orhan Pamuk', 'Doris Lessing', 'J. M. G. Le Clézio', 'Herta Müller', 'Mario Vargas Llosa', 'Tomas Tranströmer', 'Mo Yan', 'Alice Munro', 'Patrick Modiano', 'Svetlana Alexievich', 'Bob Dylan', 'Kazuo Ishiguro', 'Olga Tokarczuk[h]', 'Peter Handke', 'Louise Glück', 'Abdulrazak Gurnah', 'Annie Ernaux', 'Jon Fosse']

# %%
print(dict["Peace"])
# Out:
# ['Henry Dunant', 'Frédéric Passy', 'Élie Ducommun', 'Charles Albert Gobat', 'Randal Cremer', 'Institut de Droit International', 'Bertha von Suttner', 'Theodore Roosevelt', 'Ernesto Teodoro Moneta', 'Louis Renault', 'Klas Pontus Arnoldson', 'Fredrik Bajer', 'Auguste Beernaert', "Paul Henri Balluet d'Estournelles de Constant", 'International Peace Bureau', 'Tobias Asser', 'Alfred Hermann Fried', 'Elihu Root', 'Henri La Fontaine', 'nan', 'nan', 'nan', 'International Committee of the Red Cross', 'nan', 'Woodrow Wilson', 'Léon Bourgeois', 'Hjalmar Branting', 'Christian Lous Lange', 'Fridtjof Nansen', 'nan', 'nan', 'Austen Chamberlain', 'Charles G. Dawes', 'Aristide Briand', 'Gustav Stresemann', 'Ferdinand Buisson', 'Ludwig Quidde', 'nan', 'Frank B. Kellogg', 'Nathan Söderblom', 'Jane Addams', 'Nicholas Murray Butler', 'nan', 'Norman Angell', 'Arthur Henderson', 'Carl von Ossietzky', 'Carlos Saavedra Lamas', 'Robert Cecil, 1st Viscount Cecil of Chelwood', 'Nansen International Office for Refugees', 'nan', 'Cancelled due to World War II', 'Cancelled due to World War II', 'Cancelled due to World War II', 'nan', 'International Committee of the Red Cross', 'Cordell Hull', 'Emily Greene Balch', 'John Mott', 'Friends Service Council', 'American Friends Service Committee', 'None[c]', 'John Boyd Orr', 'Ralph Bunche', 'Léon Jouhaux', 'Albert Schweitzer', 'George Marshall', 'United Nations High Commissioner for Refugees', 'nan', 'nan', 'Lester B. Pearson', 'Dominique Pire', 'Philip Noel-Baker', 'Albert Lutuli', 'Dag Hammarskjöld', 'Linus Pauling', 'International Committee of the Red Cross', 'League of Red Cross societies', 'Martin Luther King Jr.', "United Nations International Children's Emergency Fund", 'nan', 'nan', 'René Cassin', 'International Labour Organization', 'Norman Borlaug', 'Willy Brandt', 'nan', 'Henry Kissinger', 'Lê Đức Thọ[f]', 'Seán MacBride', 'Eisaku Satō', 'Andrei Sakharov', 'Betty Williams', 'Mairead Maguire', 'Amnesty International', 'Anwar Sadat', 'Menachem Begin', 'Mother Teresa', 'Adolfo Pérez Esquivel', 'United Nations High Commissioner for Refugees', 'Alva Myrdal', 'Alfonso García Robles', 'Lech Wałęsa', 'Desmond Tutu', 'International Physicians for the Prevention of Nuclear War', 'Elie Wiesel', 'Óscar Arias', 'United Nations peacekeeping forces', 'Tenzin Gyatso (The 14th Dalai Lama)', 'Mikhail Gorbachev', 'Aung San Suu Kyi', 'Rigoberta Menchú', 'Nelson Mandela', 'F. W. de Klerk', 'Yasser Arafat', 'Shimon Peres', 'Yitzhak Rabin', 'Joseph Rotblat', 'Pugwash Conferences on Science and World Affairs', 'Carlos Filipe Ximenes Belo', 'José Ramos-Horta', 'International Campaign to Ban Landmines', 'Jody Williams', 'John Hume', 'David Trimble', 'Médecins Sans Frontières', 'Kim Dae-jung', 'United Nations', 'Kofi Annan', 'Jimmy Carter', 'Shirin Ebadi', 'Wangari Maathai', 'International Atomic Energy Agency', 'Mohamed ElBaradei', 'Muhammad Yunus', 'Grameen Bank', 'Intergovernmental Panel on Climate Change', 'Al Gore', 'Martti Ahtisaari', 'Barack Obama', 'Liu Xiaobo[g]', 'Ellen Johnson Sirleaf', 'Leymah Gbowee', 'Tawakel Karman', 'European Union', 'Organisation for the Prohibition of Chemical Weapons', 'Kailash Satyarthi', 'Malala Yousafzai', 'Tunisian National Dialogue Quartet', 'Juan Manuel Santos', 'International Campaign to Abolish Nuclear Weapons', 'Denis Mukwege', 'Nadia Murad', 'Abiy Ahmed', 'World Food Programme', 'Maria Ressa', 'Dmitry Muratov', 'Ales Bialiatski', 'Memorial', 'Centre for Civil Liberties', 'Narges Mohammadi']

# %%
print(dict["Physiology or Medicine"])
# Out:
# ['Emil von Behring', 'Ronald Ross', 'Niels Ryberg Finsen', 'Ivan Pavlov', 'Robert Koch', 'Camillo Golgi', 'Santiago Ramón y Cajal', 'Charles Louis Alphonse Laveran', 'Élie Metchnikoff', 'Paul Ehrlich', 'Emil Theodor Kocher', 'Albrecht Kossel', 'Allvar Gullstrand', 'Alexis Carrel', 'Charles Richet', 'Robert Bárány', 'nan', 'nan', 'nan', 'nan', 'Jules Bordet', 'August Krogh', 'nan', 'Archibald Hill', 'Otto Fritz Meyerhof', 'Frederick Banting', 'John Macleod', 'Willem Einthoven', 'nan', 'Johannes Fibiger', 'Julius Wagner-Jauregg', 'Charles Nicolle', 'Christiaan Eijkman', 'Frederick Gowland Hopkins', 'Karl Landsteiner', 'Otto Heinrich Warburg', 'Charles Scott Sherrington', 'Edgar Adrian', 'Thomas Hunt Morgan', 'George Whipple', 'George Minot', 'William P. Murphy', 'Hans Spemann', 'Henry Hallett Dale', 'Otto Loewi', 'Albert Szent-Györgyi', 'Corneille Heymans', 'Gerhard Domagk[b]', 'Cancelled due to World War II', 'Cancelled due to World War II', 'Cancelled due to World War II', 'Henrik Dam', 'Edward Adelbert Doisy', 'Joseph Erlanger', 'Herbert Spencer Gasser', 'Alexander Fleming', 'Ernst Chain', 'Howard Florey', 'Hermann Joseph Muller', 'Carl Ferdinand Cori', 'Gerty Cori', 'Bernardo Houssay', 'Paul Hermann Müller', 'Walter Rudolf Hess', 'António Egas Moniz', 'Philip Showalter Hench', 'Edward Calvin Kendall', 'Tadeus Reichstein', 'Max Theiler', 'Selman Waksman', 'Hans Adolf Krebs', 'Fritz Albert Lipmann', 'John Franklin Enders', 'Frederick Chapman Robbins', 'Thomas Huckle Weller', 'Hugo Theorell', 'André Frédéric Cournand', 'Werner Forssmann', 'Dickinson W. Richards', 'Daniel Bovet', 'George Beadle', 'Edward Tatum', 'Joshua Lederberg', 'Arthur Kornberg', 'Severo Ochoa', 'Macfarlane Burnet', 'Peter Medawar', 'Georg von Békésy', 'Francis Crick', 'James Watson', 'Maurice Wilkins', 'John Eccles', 'Alan Hodgkin', 'Andrew Huxley', 'Konrad Emil Bloch', 'Feodor Lynen', 'François Jacob', 'André Michel Lwoff', 'Jacques Monod', 'Francis Peyton Rous', 'Charles Brenton Huggins', 'Ragnar Granit', 'Haldan Keffer Hartline', 'George Wald', 'Robert W. Holley', 'Har Gobind Khorana', 'Marshall Warren Nirenberg', 'Max Delbrück', 'Alfred Hershey', 'Salvador Luria', 'Julius Axelrod', 'Ulf von Euler', 'Bernard Katz', 'Earl Wilbur Sutherland Jr.', 'Gerald Edelman', 'Rodney Robert Porter', 'Karl von Frisch', 'Konrad Lorenz', 'Nikolaas Tinbergen', 'Albert Claude', 'Christian de Duve', 'George Emil Palade', 'David Baltimore', 'Renato Dulbecco', 'Howard Martin Temin', 'Baruch Samuel Blumberg', 'Daniel Carleton Gajdusek', 'Roger Guillemin', 'Andrew Schally', 'Rosalyn Sussman Yalow', 'Werner Arber', 'Daniel Nathans', 'Hamilton O. Smith', 'Allan McLeod Cormack', 'Godfrey Hounsfield', 'Baruj Benacerraf', 'Jean Dausset', 'George Davis Snell', 'Roger Wolcott Sperry', 'David H. Hubel', 'Torsten Wiesel', 'Sune Bergström', 'Bengt I. Samuelsson', 'John Vane', 'Barbara McClintock', 'Niels Kaj Jerne', 'Georges J. F. Köhler', 'César Milstein', 'Michael Stuart Brown', 'Joseph L. Goldstein', 'Stanley Cohen', 'Rita Levi-Montalcini', 'Susumu Tonegawa', 'James W. Black', 'Gertrude B. Elion', 'George H. Hitchings', 'J. Michael Bishop', 'Harold E. Varmus', 'Joseph Murray', 'E. Donnall Thomas', 'Erwin Neher', 'Bert Sakmann', 'Edmond H. Fischer', 'Edwin G. Krebs', 'Richard J. Roberts', 'Phillip Allen Sharp', 'Alfred G. Gilman', 'Martin Rodbell', 'Edward B. Lewis', 'Christiane Nüsslein-Volhard', 'Eric F. Wieschaus', 'Peter C. Doherty', 'Rolf M. Zinkernagel', 'Stanley B. Prusiner', 'Robert F. Furchgott', 'Louis Ignarro', 'Ferid Murad', 'Günter Blobel', 'Arvid Carlsson', 'Paul Greengard', 'Eric Kandel', 'Leland H. Hartwell', 'Tim Hunt', 'Paul Nurse', 'Sydney Brenner', 'H. Robert Horvitz', 'John Sulston', 'Paul Lauterbur', 'Peter Mansfield', 'Richard Axel', 'Linda B. Buck', 'Barry Marshall', 'Robin Warren', 'Andrew Fire', 'Craig Mello', 'Mario Capecchi', 'Martin Evans', 'Oliver Smithies', 'Harald zur Hausen', 'Françoise Barré-Sinoussi', 'Luc Montagnier', 'Elizabeth Blackburn', 'Carol W. ...

# %%
from bs4 import BeautifulSoup

# %%
print(dict["Physics"][0])
# Out:
# Wilhelm Röntgen

# %%
URL = "https://en.m.wikipedia.org/wiki/List_of_Nobel_laureates"
page = requests.get(URL)

soup = BeautifulSoup(page.content, "html.parser")

# %%
look = ""
physics_links = []


for i in range(0,len(dict["Physics"])):   
    look = soup.find("a", string=dict["Physics"][i], href=True)
    try:
        if "/wiki/" in look["href"]:
            physics_links.append(requests.get("https://en.m.wikipedia.org" + look["href"]))
            print(look["href"])
            print(dict["Physics"][i])
    except:
        continue

chemistry_links = []
print("chems")
for i in range(0,len(dict["Chemistry"])):   
    look = soup.find("a", string=dict["Chemistry"][i], href=True)
    try:
        if "/wiki/" in look["href"]:
            physics_links.append(requests.get("https://en.m.wikipedia.org" + look["href"]))
            print(look["href"])
            print(dict["Chemistry"][i])
    except:
        continue

phys_links = []
print("physiol")
for i in range(0,len(dict["Physiology or Medicine"])):   
    look = soup.find("a", string=dict["Physiology or Medicine"][i], href=True)
    try:
        if "/wiki/" in look["href"]:
            physics_links.append(requests.get("https://en.m.wikipedia.org" + look["href"]))
            print(look["href"])
            print(dict["Physiology or Medicine"][i])
    except:
        continue

literature_links = []
print("literature")
for i in range(0,len(dict["Literature"])):   
    look = soup.find("a", string=dict["Literature"][i], href=True)
    try:
        if "/wiki/" in look["href"]:
            physics_links.append(requests.get("https://en.m.wikipedia.org" + look["href"]))
            print(look["href"])
            print(dict["Literature"][i])
    except:
        continue
peace_links = []
print("peace")
for i in range(0,len(dict["Peace"])):   
    look = soup.find("a", string=dict["Peace"][i], href=True)
    try:
        if "/wiki/" in look["href"]:
            physics_links.append(requests.get("https://en.m.wikipedia.org" + look["href"]))
            print(look["href"])
            print(dict["Peace"][i])
    except:
        continue
    
economics_links = []
print("econ")
for i in range(0,len(dict["Economics (The Sveriges Riksbank Prize)[13][a]"])):   
    look = soup.find("a", string=dict["Economics (The Sveriges Riksbank Prize)[13][a]"][i], href=True)
    try:
        if "/wiki/" in look["href"]:
            physics_links.append(requests.get("https://en.m.wikipedia.org" + look["href"]))
            print(look["href"])
            print(dict["Economics (The Sveriges Riksbank Prize)[13][a]"][i])
    except:
        continue
# Out:
# /wiki/Wilhelm_R%C3%B6ntgen
# Wilhelm Röntgen
# /wiki/Hendrik_Lorentz
# Hendrik Lorentz
# /wiki/Pieter_Zeeman
# Pieter Zeeman
# /wiki/Henri_Becquerel
# Henri Becquerel
# /wiki/Pierre_Curie
# Pierre Curie
# /wiki/Marie_Curie
# Marie Curie
# /wiki/John_Strutt,_3rd_Baron_Rayleigh
# Lord Rayleigh
# /wiki/Philipp_Lenard
# Philipp Lenard
# /wiki/J._J._Thomson
# J. J. Thomson
# /wiki/Albert_A._Michelson
# Albert A. Michelson
# /wiki/Gabriel_Lippmann
# Gabriel Lippmann
# /wiki/Karl_Ferdinand_Braun
# Karl Ferdinand Braun
# /wiki/Guglielmo_Marconi
# Guglielmo Marconi
# /wiki/Johannes_Diderik_van_der_Waals
# Johannes Diderik van der Waals
# /wiki/Wilhelm_Wien
# Wilhelm Wien
# /wiki/Gustaf_Dal%C3%A9n
# Gustaf Dalén
# /wiki/Heike_Kamerlingh_Onnes
# Heike Kamerlingh Onnes
# /wiki/Max_von_Laue
# Max von Laue
# /wiki/William_Henry_Bragg
# William Henry Bragg
# /wiki/Lawrence_Bragg
# Lawrence Bragg
# /wiki/Charles_Glover_Barkla
# Charles Glover Barkla
# /wiki/Max_Planck
# Max Planck
# /wiki/Johannes_Stark
# Johannes Stark
# /wiki/Charles_%C3%89douard_Guillaume
# Charles Édouard Guillaume
# /wiki/Albert_Einstein
# Albert Einstein
# /wiki/Niels_Bohr
# Niels Bohr
# /wiki/Robert_Andrews_Millikan
# Robert Andrews Millikan
# /wiki/Manne_Siegbahn
# Manne Siegbahn
# /wiki/James_Franck
# James Franck
# /wiki/Gustav_Ludwig_Hertz
# Gustav Ludwig Hertz
# /wiki/Jean_Baptiste_Perrin
# Jean Baptiste Perrin
# /wiki/Arthur_Compton
# Arthur Compton
# /wiki/Charles_Thomson_Rees_Wilson
# Charles Thomson Rees Wilson
# /wiki/Owen_Willans_Richardson
# Owen Willans Richardson
# /wiki/Louis_de_Broglie
# Louis de Broglie
# /wiki/C._V._Raman
# C. V. Raman
# /wiki/Werner_Heisenberg
# Werner Heisenberg
# /wiki/Erwin_Schr%C3%B6dinger
# Erwin Schrödinger
# /wiki/Paul_Dirac
# Paul Dirac
# /wiki/James_Chadwick
# James Chadwick
# /wiki/Victor_Francis_Hess
# Victor Francis Hess
# /wiki/Carl_David_Anderson
# Carl David Anderson
# /wiki/Clinton_Davisson
# Clinton Davisson
# /wiki/George_Paget_Thomson
# George Paget Thomson
# /wiki/Enrico_Fermi
# Enrico Fermi
# /wiki/Ernest_Lawrence
# Ernest Lawrence
# /wiki/Otto_Stern
# Otto Stern
# /wiki/Isidor_Isaac_Rabi
# Isidor Isaac Rabi
# /wiki/Wolfgang_Pauli
# Wolfgang Pauli
# /wiki/Percy_Williams_Bridgman
# Percy Williams Bridgman
# /wiki/Edward_Victor_Appleton
# Edward Victor Appleton
# /wiki/Patrick_Blackett
# Patrick Blackett
# /wiki/Hideki_Yukawa
# Hideki Yukawa
# /wiki/C._F._Powell
# C. F. Powell
# /wiki/John_Cockcroft
# John Cockcroft
# /wiki/Ernest_Walton
# Ernest Walton
# /wiki/Felix_Bloch
# Felix Bloch
# /wiki/Edward_Mills_Purcell
# Edward Mills Purcell
# /wiki/Frits_Zernike
# Frits Zernike
# /wiki/Max_Born
# Max Born
# /wiki/Walther_Bothe
# Walther Bothe
# /wiki/Willis_Lamb
# Willis Lamb
# /wiki/Polykarp_Kusch
# Polykarp Kusch
# /wiki/John_Bardeen
# John Bardeen
# /wiki/Walter_Houser_Brattain
# Walter Houser Brattain
# /wiki/William_Shockley
# William Shockley
# /wiki/Yang_Chen-Ning
# Yang Chen-Ning
# /wiki/Tsung-Dao_Lee
# Tsung-Dao Lee
# /wiki/Pavel_Cherenkov
# Pavel Cherenkov
# /wiki/Ilya_Frank
# Ilya Frank
# /wiki/Igor_Tamm
# Igor Tamm
# /wiki/Emilio_Segr%C3%A8
# Emilio Segrè
# /wiki/Owen_Chamberlain
# Owen Chamberlain
# /wiki/Donald_A._Glaser
# Donald A. Glaser
# /wiki/Robert_Hofstadter
# Robert Hofstadter
# /wiki/Rudolf_M%C3%B6ssbauer
# Rudolf Mössbauer
# /wiki/Lev_Landau
# Lev Landau
# /wiki/Eugene_Wigner
# Eugene Wigner
# /wiki/Maria_Goeppert_Mayer
# Maria Goeppert Mayer
# /wiki/J._Hans_D._Jensen
# J. Hans D. Jensen
# /wiki/Charles_H._Townes
# Charles H. Townes
# /wiki/Nikolay_Basov
# Nikolay Basov
# /wiki/Alexander_Prokhorov
# Alexander Prokhorov
# /wiki/Shin%27ichir%C5%8D_Tomonaga
# Shin'ichirō Tomonaga
# /wiki/Julian_Schwinger
# Julian Schwinger
# /wiki/Richard_Feynman
# Richard Feynman
# /wiki/Alfred_Kastler
# Alfred Kastler
# /wiki/Hans_Bethe
# Hans Bethe
# /wiki/Luis_Walter_Alvarez
# Luis Walter Alvarez
# /wiki/Murray_Gell-Mann
# Murray Gell-Mann
# /wiki/Hannes_Alfv%C3%A9n
# Hannes Alfvén
# /wiki/Louis_N%C3%A9el
# Louis Néel
# /wiki/Dennis_Gabor
# Dennis Gabor
# /wiki/John_Bardeen
# John Bardeen
# /wiki/Leon_Cooper
# Leon Cooper
# /wiki/John_Robert_Schrieffer
# John Robert Schrieffer
# /wiki/Leo_Esaki
# Leo Esaki
# /wiki/Ivar_Giaever
# Ivar Giaever
# /wiki/Brian_Josephson
# Brian Josephson
# /wiki/Martin_Ryle
# Martin Ryle
# /wiki/Antony_Hewish
# Antony Hewish
# /wiki/Aage_Bohr
# Aage Bohr
# /wiki/Ben_Roy_Mottelson
# Ben Roy Mottelson
# /wiki/James_Rainwater
# James Rainwater
# /wiki/Burton_Richter
# Burton Richter
# /wiki/Samuel_C._C._Ting
# Samuel C. C. Ting
# /wiki/Philip_W._Anderson
# Philip W. Anderson
# /wiki/Nevill_Francis_Mott
# Nevill Francis Mott
# /wiki/John_Hasbrouck_Van_Vleck
# John Hasbrouck Van Vleck
# /wiki/Pyotr_Kapitsa
# Pyotr Kapitsa
# /wiki/Arno_Allan_Penzias
# Arno Allan Penzias
# /wiki/Robert_Woodrow_Wilson
# Robert Woodrow Wilson
# /wiki/Sheldon_Glashow
# Sheldon Glashow
# /wiki/Abdus_Salam
# Abdus Salam
# /wiki/Steven_Weinberg
# Steven Weinberg
# /wiki/James_Cronin
# James Cronin
# /wiki/Val_Logsdon_Fitch
# Val Logsdon Fitch
# /wiki/Nicolaas_Bloembergen
# Nicolaas Bloembergen
# /wiki/Arthur_Leonard_Schawlow
# Arthur Leonard Schawlow
# /wiki/Kai_Siegbahn
# Kai Siegbahn
# /wiki/Kenneth_G._Wilson
# Kenneth G. Wilson
# /wiki/Subrahmanyan_Chandrasekhar
# Subrahmanyan Chandrasekhar
# /wiki/William_Alfred_Fowler
# William Alfred Fowler
# /wiki/Carlo_Rubbia
# Carlo Rubbia
# /wiki/Simon_van_der_Meer
# Simon van der Meer
# /wiki/Klaus_von_Klitzing
# Klaus von Klitzing
# /wiki/Ernst_Ruska
# Ernst Ruska
# /wiki/Gerd_Binnig
# Gerd Binnig
# /wiki/Heinrich_Rohrer
# Heinrich Rohrer
# /wiki/Georg_Bednorz
# Georg Bednorz
# /wiki/K._Alex_M%C3%BCller
# K. Alex Müller
# /wiki/Leon_M._Lederman
# Leon M. Lederman
# /wiki/Melvin_Schwartz
# Melvin Schwartz
# /wiki/Jack_Steinberger
# Jack Steinberger
# /wiki/Norman_Ramsey_Jr.
# Norman Ramsey Jr.
# /wiki/Hans_Georg_Dehmelt
# Hans Georg Dehmelt
# /wiki/Wolfgang_Paul
# Wolfgang Paul
# /wiki/Jerome_Isaac_Friedman
# Jerome Isaac Friedman
# /wiki/Henry_Way_Kendall
# Henry Way Kendall
# /wiki/Richard_E._Taylor
# Richard E. Taylor
# /wiki/Pierre-Gilles_de_Gennes
# Pierre-Gilles de Gennes
# /wiki/Georges_Charpak
# Georges Charpak
# /wiki/Russell_Alan_Hulse
# Russell Alan Hulse
# /wiki/Joseph_Hooton_Taylor_Jr.
# Joseph Hooton Taylor Jr.
# /wiki/Bertram_Brockhouse
# Bertram Brockhouse
# /wiki/Clifford_Shull
# Clifford Shull
# /wiki/Martin_Lewis_Perl
# Martin Lewis Perl
# /wiki/Frederick_Reines
# Frederick Reines
# /wiki/David_Lee_(physicist)
# David Lee
# /wiki/Douglas_Osheroff
# Douglas Osheroff
# /wiki/Robert_Coleman_Richardson
# Robert Coleman Richardson
# /wiki/Steven_Chu
# Steven Chu
# /wiki/Claude_Cohen-Tannoudji
# Claude Cohen-Tannoudji
# /wiki/William_Daniel_Phillips
# William Daniel Phillips
# /wiki/Robert_B._Laughlin
# Robert B. Laughlin
# /wiki/Horst_Ludwig_St%C3%B6rmer
# Horst Ludwig Störmer
# /wiki/Daniel_C._Tsui
# Daniel C. Tsui
# /wiki/Gerard_%27t_Hooft
# Gerard 't Hooft
# /wiki/Martinus_J._G._Veltman
# Martinus J. G. Veltman
# /wiki/Jack_Kilby
# Jack Kilby
# /wiki/Zhores_Alferov
# Zhores Alferov
# /wiki/Herbert_Kroemer
# Herbert Kroemer
# /wiki/Eric_Allin_Cornell
# Eric Allin Cornell
# /wiki/Wolfgang_Ketterle
# Wolfgang Ketterle
# /wiki/Carl_Wieman
# Carl Wieman
# /wiki/Riccardo_Giacconi
# Riccardo Giacconi
# /wiki/Raymond_Davis_Jr.
# Raymond Davis Jr.
# /wiki/Masatoshi_Koshiba
# Masatoshi Koshiba
# /wiki/Alexei_Abrikosov_(physicist)
# Alexei Abrikosov
# /wiki/Vitaly_Ginzburg
# Vitaly Ginzburg
# /wiki/Anthony_James_Leggett
# Anthony James Leggett
# /wiki/David_Gross
# David Gross
# /wiki/Hugh_David_Politzer
# Hugh David Politzer
# /wiki/Frank_Wilczek
# Frank Wilczek
# /wiki/Roy_J._Glauber
# Roy J. Glauber
# /wiki/John_L._Hall
# John L. Hall
# /wiki/Theodor_W._H%C3%A4nsch
# Theodor W. Hänsch
# /wiki/John_C._Mather
# John C. Mather
# /wiki/George_Smoot
# George Smoot
# /wiki/Albert_Fert
# Albert Fert
# /wiki/Peter_Gr%C3%BCnberg
# Peter Grünberg
# /wiki/Yoichiro_Nambu
# Yoichiro Nambu
# /wiki/Makoto_Kobayashi_(physicist)
# Makoto Kobayashi
# /wiki/Toshihide_Maskawa
# Toshihide Maskawa
# /wiki/Charles_K._Kao
# Charles K. Kao
# /wiki/Willard_Boyle
# Willard S. Boyle
# /wiki/George_E._Smith
# George E. Smith
# /wiki/Andre_Geim
# Andre Geim
# /wiki/Konstantin_Novoselov
# Konstantin Novoselov
# /wiki/Saul_Perlmutter
# Saul Perlmutter
# /wiki/Adam_Riess
# Adam Riess
# /wiki/Brian_Schmidt
# Brian Schmidt
# /wiki/Serge_Haroche
# Serge Haroche
# /wiki/David_J._Wineland
# David J. Wineland
# /wiki/Fran%C3%A7ois_Englert
# François Englert
# /wiki/Peter_Higgs
# Peter W. Higgs
# /wiki/Isamu_Akasaki
# Isamu Akasaki
# /wiki/Hiroshi_Amano
# Hiroshi Amano
# /wiki/Shuji_Nakamura
# Shuji Nakamura
# /wiki/Takaaki_Kajita
# Takaaki Kajita
# /wiki/Arthur_B._McDonald
# Arthur B. McDonald
# /wiki/David_J._Thouless
# David J. Thouless
# /wiki/Duncan_Haldane
# Duncan Haldane
# /wiki/John_M._Kosterlitz
# John M. Kosterlitz
# /wiki/Rainer_Weiss
# Rainer Weiss
# /wiki/Barry_Barish
# Barry Barish
# /wiki/Kip_Thorne
# Kip Thorne
# /wiki/Arthur_Ashkin
# Arthur Ashkin
# /wiki/G%C3%A9rard_Mourou
# Gérard Mourou
# /wiki/Donna_Strickland
# Donna Strickland
# /wiki/Jim_Peebles
# Jim Peebles
# /wiki/Michel_Mayor
# Michel Mayor
# /wiki/Didier_Queloz
# Didier Queloz
# /wiki/Roger_Penrose
# Roger Penrose
# /wiki/Reinhard_Genzel
# Reinhard Genzel
# /wiki/Andrea_M._Ghez
# Andrea M. Ghez
# /wiki/Giorgio_Parisi
# Giorgio Parisi
# /wiki/Klaus_Hasselmann
# Klaus Hasselmann
# /wiki/Syukuro_Manabe
# Syukuro Manabe
# /wiki/Alain_Aspect
# Alain Aspect
# /wiki/John_Clauser
# John Clauser
# /wiki/Anton_Zeilinger
# Anton Zeilinger
# /wiki/Pierre_Agostini
# Pierre Agostini
# /wiki/Ferenc_Krausz
# Ferenc Krausz
# /wiki/Anne_L%27Huillier
# Anne L'Huillier
# /wiki/Jacobus_Henricus_van_%27t_Hoff
# Jacobus Henricus van 't Hoff
# /wiki/Emil_Fischer
# Emil Fischer
# /wiki/Svante_Arrhenius
# Svante Arrhenius
# /wiki/William_Ramsay
# William Ramsay
# /wiki/Adolf_von_Baeyer
# Adolf von Baeyer
# /wiki/Henri_Moissan
# Henri Moissan
# /wiki/Eduard_Buchner
# Eduard Buchner
# /wiki/Ernest_Rutherford
# Ernest Rutherford
# /wiki/Wilhelm_Ostwald
# Wilhelm Ostwald
# /wiki/Otto_Wallach
# Otto Wallach
# /wiki/Marie_Curie
# Marie Curie
# /wiki/Victor_Grignard
# Victor Grignard
# /wiki/Paul_Sabatier_(chemist)
# Paul Sabatier
# /wiki/Alfred_Werner
# Alfred Werner
# /wiki/Theodore_William_Richards
# Theodore William Richards
# /wiki/Richard_Willst%C3%A4tter
# Richard Willstätter
# /wiki/Fritz_Haber
# Fritz Haber
# /wiki/Walther_Nernst
# Walther Nernst
# /wiki/Frederick_Soddy
# Frederick Soddy
# /wiki/Francis_William_Aston
# Francis William Aston
# /wiki/Fritz_Pregl
# Fritz Pregl
# /wiki/Richard_Adolf_Zsigmondy
# Richard Adolf Zsigmondy
# /wiki/Theodor_Svedberg
# Theodor Svedberg
# /wiki/Heinrich_Otto_Wieland
# Heinrich Otto Wieland
# /wiki/Adolf_Windaus
# Adolf Windaus
# /wiki/Arthur_Harden
# Arthur Harden
# /wiki/Hans_von_Euler-Chelpin
# Hans von Euler-Chelpin
# /wiki/Hans_Fischer
# Hans Fischer
# /wiki/Carl_Bosch
# Carl Bosch
# /wiki/Friedrich_Bergius
# Friedrich Bergius
# /wiki/Irving_Langmuir
# Irving Langmuir
# /wiki/Harold_Urey
# Harold Urey
# /wiki/Fr%C3%A9d%C3%A9ric_Joliot-Curie
# Frédéric Joliot-Curie
# /wiki/Ir%C3%A8ne_Joliot-Curie
# Irène Joliot-Curie
# /wiki/Peter_Debye
# Peter Debye
# /wiki/Norman_Haworth
# Norman Haworth
# /wiki/Paul_Karrer
# Paul Karrer
# /wiki/George_de_Hevesy
# George de Hevesy
# /wiki/Otto_Hahn
# Otto Hahn
# /wiki/Artturi_Ilmari_Virtanen
# Artturi Ilmari Virtanen
# /wiki/James_B._Sumner
# James B. Sumner
# /wiki/John_Howard_Northrop
# John Howard Northrop
# /wiki/Wendell_Meredith_Stanley
# Wendell Meredith Stanley
# /wiki/Robert_Robinson_(organic_chemist)
# Robert Robinson
# /wiki/Arne_Tiselius
# Arne Tiselius
# /wiki/William_Giauque
# William Giauque
# /wiki/Otto_Diels
# Otto Diels
# /wiki/Kurt_Alder
# Kurt Alder
# /wiki/Edwin_McMillan
# Edwin McMillan
# /wiki/Glenn_T._Seaborg
# Glenn T. Seaborg
# /wiki/Archer_Martin
# Archer Martin
# /wiki/Richard_Laurence_Millington_Synge
# Richard Laurence Millington Synge
# /wiki/Hermann_Staudinger
# Hermann Staudinger
# /wiki/Linus_Pauling
# Linus Pauling
# /wiki/Vincent_du_Vigneaud
# Vincent du Vigneaud
# /wiki/Cyril_Norman_Hinshelwood
# Cyril Norman Hinshelwood
# /wiki/Nikolay_Semyonov
# Nikolay Semyonov
# /wiki/Alexander_R._Todd
# The Lord Todd
# /wiki/Frederick_Sanger
# Frederick Sanger
# /wiki/Jaroslav_Heyrovsk%C3%BD
# Jaroslav Heyrovský
# /wiki/Willard_Libby
# Willard Libby
# /wiki/Melvin_Calvin
# Melvin Calvin
# /wiki/Max_Perutz
# Max Perutz
# /wiki/John_Kendrew
# John Kendrew
# /wiki/Karl_Ziegler
# Karl Ziegler
# /wiki/Giulio_Natta
# Giulio Natta
# /wiki/Dorothy_Hodgkin
# Dorothy Hodgkin
# /wiki/Robert_Burns_Woodward
# Robert Burns Woodward
# /wiki/Robert_S._Mulliken
# Robert S. Mulliken
# /wiki/Manfred_Eigen
# Manfred Eigen
# /wiki/Ronald_George_Wreyford_Norrish
# Ronald George Wreyford Norrish
# /wiki/George_Porter
# George Porter
# /wiki/Lars_Onsager
# Lars Onsager
# /wiki/Derek_Barton
# Derek Barton
# /wiki/Odd_Hassel
# Odd Hassel
# /wiki/Luis_Federico_Leloir
# Luis Federico Leloir
# /wiki/Gerhard_Herzberg
# Gerhard Herzberg
# /wiki/Christian_B._Anfinsen
# Christian B. Anfinsen
# /wiki/Stanford_Moore
# Stanford Moore
# /wiki/William_Howard_Stein
# William Howard Stein
# /wiki/Ernst_Otto_Fischer
# Ernst Otto Fischer
# /wiki/Geoffrey_Wilkinson
# Geoffrey Wilkinson
# /wiki/Paul_Flory
# Paul Flory
# /wiki/John_Cornforth
# John Cornforth
# /wiki/Vladimir_Prelog
# Vladimir Prelog
# /wiki/William_Lipscomb
# William Lipscomb
# /wiki/Ilya_Prigogine
# Ilya Prigogine
# /wiki/Peter_D._Mitchell
# Peter D. Mitchell
# /wiki/Herbert_C._Brown
# Herbert C. Brown
# /wiki/Georg_Wittig
# Georg Wittig
# /wiki/Paul_Berg
# Paul Berg
# /wiki/Walter_Gilbert
# Walter Gilbert
# /wiki/Frederick_Sanger
# Frederick Sanger
# /wiki/Kenichi_Fukui
# Kenichi Fukui
# /wiki/Roald_Hoffmann
# Roald Hoffmann
# /wiki/Aaron_Klug
# Aaron Klug
# /wiki/Henry_Taube
# Henry Taube
# /wiki/Robert_Bruce_Merrifield
# Robert Bruce Merrifield
# /wiki/Herbert_A._Hauptman
# Herbert A. Hauptman
# /wiki/Jerome_Karle
# Jerome Karle
# /wiki/Dudley_R._Herschbach
# Dudley R. Herschbach
# /wiki/Yuan_T._Lee
# Yuan T. Lee
# /wiki/John_Polanyi
# John Polanyi
# /wiki/Donald_J._Cram
# Donald J. Cram
# /wiki/Jean-Marie_Lehn
# Jean-Marie Lehn
# /wiki/Charles_J._Pedersen
# Charles J. Pedersen
# /wiki/Johann_Deisenhofer
# Johann Deisenhofer
# /wiki/Robert_Huber
# Robert Huber
# /wiki/Hartmut_Michel
# Hartmut Michel
# /wiki/Sidney_Altman
# Sidney Altman
# /wiki/Thomas_Cech
# Thomas Cech
# /wiki/Elias_James_Corey
# Elias James Corey
# /wiki/Richard_R._Ernst
# Richard R. Ernst
# /wiki/Rudolph_A._Marcus
# Rudolph A. Marcus
# /wiki/Kary_Mullis
# Kary Mullis
# /wiki/Michael_Smith_(chemist)
# Michael Smith
# /wiki/George_Andrew_Olah
# George Andrew Olah
# /wiki/Paul_J._Crutzen
# Paul J. Crutzen
# /wiki/Mario_J._Molina
# Mario J. Molina
# /wiki/F._Sherwood_Rowland
# F. Sherwood Rowland
# /wiki/Robert_Curl
# Robert Curl
# /wiki/Harry_Kroto
# Harry Kroto
# /wiki/Richard_Smalley
# Richard Smalley
# /wiki/Paul_D._Boyer
# Paul D. Boyer
# /wiki/John_E._Walker
# John E. Walker
# /wiki/Jens_Christian_Skou
# Jens Christian Skou
# /wiki/Walter_Kohn
# Walter Kohn
# /wiki/John_Pople
# John Pople
# /wiki/Ahmed_Zewail
# Ahmed Zewail
# /wiki/Alan_J._Heeger
# Alan J. Heeger
# /wiki/Alan_MacDiarmid
# Alan MacDiarmid
# /wiki/Hideki_Shirakawa
# Hideki Shirakawa
# /wiki/William_Standish_Knowles
# William Standish Knowles
# /wiki/Ry%C5%8Dji_Noyori
# Ryōji Noyori
# /wiki/Karl_Barry_Sharpless
# Karl Barry Sharpless
# /wiki/John_B._Fenn
# John B. Fenn
# /wiki/Koichi_Tanaka
# Koichi Tanaka
# /wiki/Kurt_W%C3%BCthrich
# Kurt Wüthrich
# /wiki/Peter_Agre
# Peter Agre
# /wiki/Roderick_MacKinnon
# Roderick MacKinnon
# /wiki/Aaron_Ciechanover
# Aaron Ciechanover
# /wiki/Avram_Hershko
# Avram Hershko
# /wiki/Irwin_Rose
# Irwin Rose
# /wiki/Yves_Chauvin
# Yves Chauvin
# /wiki/Robert_H._Grubbs
# Robert H. Grubbs
# /wiki/Richard_R._Schrock
# Richard R. Schrock
# /wiki/Roger_D._Kornberg
# Roger D. Kornberg
# /wiki/Gerhard_Ertl
# Gerhard Ertl
# /wiki/Osamu_Shimomura
# Osamu Shimomura
# /wiki/Martin_Chalfie
# Martin Chalfie
# /wiki/Roger_Y._Tsien
# Roger Y. Tsien
# /wiki/Venkatraman_Ramakrishnan
# Venkatraman Ramakrishnan
# /wiki/Thomas_A._Steitz
# Thomas A. Steitz
# /wiki/Ada_Yonath
# Ada Yonath
# /wiki/Richard_F._Heck
# Richard F. Heck
# /wiki/Ei-ichi_Negishi
# Ei-ichi Negishi
# /wiki/Akira_Suzuki_(chemist)
# Akira Suzuki
# /wiki/Dan_Shechtman
# Dan Shechtman
# /wiki/Brian_Kobilka
# Brian K. Kobilka
# /wiki/Robert_J._Lefkowitz
# Robert J. Lefkowitz
# /wiki/Martin_Karplus
# Martin Karplus
# /wiki/Michael_Levitt
# Michael Levitt
# /wiki/Arieh_Warshel
# Arieh Warshel
# /wiki/Eric_Betzig
# Eric Betzig
# /wiki/Stefan_Hell
# Stefan Hell
# /wiki/William_Moerner
# William Moerner
# /wiki/Tomas_Lindahl
# Tomas Lindahl
# /wiki/Paul_Modrich
# Paul L. Modrich
# /wiki/Aziz_Sancar
# Aziz Sancar
# /wiki/Jean-Pierre_Sauvage
# Jean-Pierre Sauvage
# /wiki/Fraser_Stoddart
# Fraser Stoddart
# /wiki/Ben_Feringa
# Ben Feringa
# /wiki/Jacques_Dubochet
# Jacques Dubochet
# /wiki/Joachim_Frank
# Joachim Frank
# /wiki/Richard_Henderson_(biologist)
# Richard Henderson
# /wiki/Frances_H._Arnold
# Frances H. Arnold
# /wiki/George_Smith_(chemist)
# George Smith
# /wiki/Greg_Winter
# Greg Winter
# /wiki/John_B._Goodenough
# John B. Goodenough
# /wiki/M._Stanley_Whittingham
# M. Stanley Whittingham
# /wiki/Akira_Yoshino
# Akira Yoshino
# /wiki/Emmanuelle_Charpentier
# Emmanuelle Charpentier
# /wiki/Jennifer_Doudna
# Jennifer Doudna
# /wiki/Benjamin_List
# Benjamin List
# /wiki/David_MacMillan
# David MacMillan
# /wiki/Carolyn_Bertozzi
# Carolyn Bertozzi
# /wiki/Morten_P._Meldal
# Morten P. Meldal
# /wiki/Karl_Barry_Sharpless
# Karl Barry Sharpless
# /wiki/Moungi_Bawendi
# Moungi Bawendi
# /wiki/Louis_E._Brus
# Louis E. Brus
# /wiki/Alexey_Ekimov
# Alexey Ekimov
# /wiki/Emil_von_Behring
# Emil von Behring
# /wiki/Ronald_Ross
# Ronald Ross
# /wiki/Niels_Ryberg_Finsen
# Niels Ryberg Finsen
# /wiki/Ivan_Pavlov
# Ivan Pavlov
# /wiki/Robert_Koch
# Robert Koch
# /wiki/Camillo_Golgi
# Camillo Golgi
# /wiki/Santiago_Ram%C3%B3n_y_Cajal
# Santiago Ramón y Cajal
# /wiki/Charles_Louis_Alphonse_Laveran
# Charles Louis Alphonse Laveran
# /wiki/%C3%89lie_Metchnikoff
# Élie Metchnikoff
# /wiki/Paul_Ehrlich
# Paul Ehrlich
# /wiki/Emil_Theodor_Kocher
# Emil Theodor Kocher
# /wiki/Albrecht_Kossel
# Albrecht Kossel
# /wiki/Allvar_Gullstrand
# Allvar Gullstrand
# /wiki/Alexis_Carrel
# Alexis Carrel
# /wiki/Charles_Richet
# Charles Richet
# /wiki/Robert_B%C3%A1r%C3%A1ny
# Robert Bárány
# /wiki/Jules_Bordet
# Jules Bordet
# /wiki/August_Krogh
# August Krogh
# /wiki/Archibald_Hill
# Archibald Hill
# /wiki/Otto_Fritz_Meyerhof
# Otto Fritz Meyerhof
# /wiki/Frederick_Banting
# Frederick Banting
# /wiki/John_Macleod_(physiologist)
# John Macleod
# /wiki/Willem_Einthoven
# Willem Einthoven
# /wiki/Johannes_Fibiger
# Johannes Fibiger
# /wiki/Julius_Wagner-Jauregg
# Julius Wagner-Jauregg
# /wiki/Charles_Nicolle
# Charles Nicolle
# /wiki/Christiaan_Eijkman
# Christiaan Eijkman
# /wiki/Frederick_Gowland_Hopkins
# Frederick Gowland Hopkins
# /wiki/Karl_Landsteiner
# Karl Landsteiner
# /wiki/Otto_Heinrich_Warburg
# Otto Heinrich Warburg
# /wiki/Charles_Scott_Sherrington
# Charles Scott Sherrington
# /wiki/Edgar_Adrian
# Edgar Adrian
# /wiki/Thomas_Hunt_Morgan
# Thomas Hunt Morgan
# /wiki/George_Whipple
# George Whipple
# /wiki/George_Minot
# George Minot
# /wiki/William_P._Murphy
# William P. Murphy
# /wiki/Hans_Spemann
# Hans Spemann
# /wiki/Henry_Hallett_Dale
# Henry Hallett Dale
# /wiki/Otto_Loewi
# Otto Loewi
# /wiki/Albert_Szent-Gy%C3%B6rgyi
# Albert Szent-Györgyi
# /wiki/Corneille_Heymans
# Corneille Heymans
# /wiki/Henrik_Dam
# Henrik Dam
# /wiki/Edward_Adelbert_Doisy
# Edward Adelbert Doisy
# /wiki/Joseph_Erlanger
# Joseph Erlanger
# /wiki/Herbert_Spencer_Gasser
# Herbert Spencer Gasser
# /wiki/Alexander_Fleming
# Alexander Fleming
# /wiki/Ernst_Chain
# Ernst Chain
# /wiki/Howard_Florey
# Howard Florey
# /wiki/Hermann_Joseph_Muller
# Hermann Joseph Muller
# /wiki/Carl_Ferdinand_Cori
# Carl Ferdinand Cori
# /wiki/Gerty_Cori
# Gerty Cori
# /wiki/Bernardo_Houssay
# Bernardo Houssay
# /wiki/Paul_Hermann_M%C3%BCller
# Paul Hermann Müller
# /wiki/Walter_Rudolf_Hess
# Walter Rudolf Hess
# /wiki/Ant%C3%B3nio_Egas_Moniz
# António Egas Moniz
# /wiki/Philip_Showalter_Hench
# Philip Showalter Hench
# /wiki/Edward_Calvin_Kendall
# Edward Calvin Kendall
# /wiki/Tadeus_Reichstein
# Tadeus Reichstein
# /wiki/Max_Theiler
# Max Theiler
# /wiki/Selman_Waksman
# Selman Waksman
# /wiki/Hans_Adolf_Krebs
# Hans Adolf Krebs
# /wiki/Fritz_Albert_Lipmann
# Fritz Albert Lipmann
# /wiki/John_Franklin_Enders
# John Franklin Enders
# /wiki/Frederick_Chapman_Robbins
# Frederick Chapman Robbins
# /wiki/Thomas_Huckle_Weller
# Thomas Huckle Weller
# /wiki/Hugo_Theorell
# Hugo Theorell
# /wiki/Andr%C3%A9_Fr%C3%A9d%C3%A9ric_Cournand
# André Frédéric Cournand
# /wiki/Werner_Forssmann
# Werner Forssmann
# /wiki/Dickinson_W._Richards
# Dickinson W. Richards
# /wiki/Daniel_Bovet
# Daniel Bovet
# /wiki/George_Beadle
# George Beadle
# /wiki/Edward_Tatum
# Edward Tatum
# /wiki/Joshua_Lederberg
# Joshua Lederberg
# /wiki/Arthur_Kornberg
# Arthur Kornberg
# /wiki/Severo_Ochoa
# Severo Ochoa
# /wiki/Macfarlane_Burnet
# Macfarlane Burnet
# /wiki/Peter_Medawar
# Peter Medawar
# /wiki/Georg_von_B%C3%A9k%C3%A9sy
# Georg von Békésy
# /wiki/Francis_Crick
# Francis Crick
# /wiki/James_Watson
# James Watson
# /wiki/Maurice_Wilkins
# Maurice Wilkins
# /wiki/John_Eccles_(neurophysiologist)
# John Eccles
# /wiki/Alan_Hodgkin
# Alan Hodgkin
# /wiki/Andrew_Huxley
# Andrew Huxley
# /wiki/Konrad_Emil_Bloch
# Konrad Emil Bloch
# /wiki/Feodor_Lynen
# Feodor Lynen
# /wiki/Fran%C3%A7ois_Jacob
# François Jacob
# /wiki/Andr%C3%A9_Michel_Lwoff
# André Michel Lwoff
# /wiki/Jacques_Monod
# Jacques Monod
# /wiki/Francis_Peyton_Rous
# Francis Peyton Rous
# /wiki/Charles_Brenton_Huggins
# Charles Brenton Huggins
# /wiki/Ragnar_Granit
# Ragnar Granit
# /wiki/Haldan_Keffer_Hartline
# Haldan Keffer Hartline
# /wiki/George_Wald
# George Wald
# /wiki/Robert_W._Holley
# Robert W. Holley
# /wiki/Har_Gobind_Khorana
# Har Gobind Khorana
# /wiki/Marshall_Warren_Nirenberg
# Marshall Warren Nirenberg
# /wiki/Max_Delbr%C3%BCck
# Max Delbrück
# /wiki/Alfred_Hershey
# Alfred Hershey
# /wiki/Salvador_Luria
# Salvador Luria
# /wiki/Julius_Axelrod
# Julius Axelrod
# /wiki/Ulf_von_Euler
# Ulf von Euler
# /wiki/Bernard_Katz
# Bernard Katz
# /wiki/Earl_Wilbur_Sutherland_Jr.
# Earl Wilbur Sutherland Jr.
# /wiki/Gerald_Edelman
# Gerald Edelman
# /wiki/Rodney_Robert_Porter
# Rodney Robert Porter
# /wiki/Karl_von_Frisch
# Karl von Frisch
# /wiki/Konrad_Lorenz
# Konrad Lorenz
# /wiki/Nikolaas_Tinbergen
# Nikolaas Tinbergen
# /wiki/Albert_Claude
# Albert Claude
# /wiki/Christian_de_Duve
# Christian de Duve
# /wiki/George_Emil_Palade
# George Emil Palade
# /wiki/David_Baltimore
# David Baltimore
# /wiki/Renato_Dulbecco
# Renato Dulbecco
# /wiki/Howard_Martin_Temin
# Howard Martin Temin
# /wiki/Baruch_Samuel_Blumberg
# Baruch Samuel Blumberg
# /wiki/Daniel_Carleton_Gajdusek
# Daniel Carleton Gajdusek
# /wiki/Roger_Guillemin
# Roger Guillemin
# /wiki/Andrew_Schally
# Andrew Schally
# /wiki/Rosalyn_Sussman_Yalow
# Rosalyn Sussman Yalow
# /wiki/Werner_Arber
# Werner Arber
# /wiki/Daniel_Nathans
# Daniel Nathans
# /wiki/Hamilton_O._Smith
# Hamilton O. Smith
# /wiki/Allan_McLeod_Cormack
# Allan McLeod Cormack
# /wiki/Godfrey_Hounsfield
# Godfrey Hounsfield
# /wiki/Baruj_Benacerraf
# Baruj Benacerraf
# /wiki/Jean_Dausset
# Jean Dausset
# /wiki/George_Davis_Snell
# George Davis Snell
# /wiki/Roger_Wolcott_Sperry
# Roger Wolcott Sperry
# /wiki/David_H._Hubel
# David H. Hubel
# /wiki/Torsten_Wiesel
# Torsten Wiesel
# /wiki/Sune_Bergstr%C3%B6m
# Sune Bergström
# /wiki/Bengt_I._Samuelsson
# Bengt I. Samuelsson
# /wiki/John_Vane
# John Vane
# /wiki/Barbara_McClintock
# Barbara McClintock
# /wiki/Niels_Kaj_Jerne
# Niels Kaj Jerne
# /wiki/Georges_J._F._K%C3%B6hler
# Georges J. F. Köhler
# /wiki/C%C3%A9sar_Milstein
# César Milstein
# /wiki/Michael_Stuart_Brown
# Michael Stuart Brown
# /wiki/Joseph_L._Goldstein
# Joseph L. Goldstein
# /wiki/Stanley_Cohen_(biochemist)
# Stanley Cohen
# /wiki/Rita_Levi-Montalcini
# Rita Levi-Montalcini
# /wiki/Susumu_Tonegawa
# Susumu Tonegawa
# /wiki/James_W._Black
# James W. Black
# /wiki/Gertrude_B._Elion
# Gertrude B. Elion
# /wiki/George_H._Hitchings
# George H. Hitchings
# /wiki/J._Michael_Bishop
# J. Michael Bishop
# /wiki/Harold_E._Varmus
# Harold E. Varmus
# /wiki/Joseph_Murray
# Joseph Murray
# /wiki/E._Donnall_Thomas
# E. Donnall Thomas
# /wiki/Erwin_Neher
# Erwin Neher
# /wiki/Bert_Sakmann
# Bert Sakmann
# /wiki/Edmond_H._Fischer
# Edmond H. Fischer
# /wiki/Edwin_G._Krebs
# Edwin G. Krebs
# /wiki/Richard_J._Roberts
# Richard J. Roberts
# /wiki/Phillip_Allen_Sharp
# Phillip Allen Sharp
# /wiki/Alfred_G._Gilman
# Alfred G. Gilman
# /wiki/Martin_Rodbell
# Martin Rodbell
# /wiki/Edward_B._Lewis
# Edward B. Lewis
# /wiki/Christiane_N%C3%BCsslein-Volhard
# Christiane Nüsslein-Volhard
# /wiki/Eric_F._Wieschaus
# Eric F. Wieschaus
# /wiki/Peter_C._Doherty
# Peter C. Doherty
# /wiki/Rolf_M._Zinkernagel
# Rolf M. Zinkernagel
# /wiki/Stanley_B._Prusiner
# Stanley B. Prusiner
# /wiki/Robert_F._Furchgott
# Robert F. Furchgott
# /wiki/Louis_Ignarro
# Louis Ignarro
# /wiki/Ferid_Murad
# Ferid Murad
# /wiki/G%C3%BCnter_Blobel
# Günter Blobel
# /wiki/Arvid_Carlsson
# Arvid Carlsson
# /wiki/Paul_Greengard
# Paul Greengard
# /wiki/Eric_Kandel
# Eric Kandel
# /wiki/Leland_H._Hartwell
# Leland H. Hartwell
# /wiki/Tim_Hunt
# Tim Hunt
# /wiki/Paul_Nurse
# Paul Nurse
# /wiki/Sydney_Brenner
# Sydney Brenner
# /wiki/H._Robert_Horvitz
# H. Robert Horvitz
# /wiki/John_Sulston
# John Sulston
# /wiki/Paul_Lauterbur
# Paul Lauterbur
# /wiki/Peter_Mansfield
# Peter Mansfield
# /wiki/Richard_Axel
# Richard Axel
# /wiki/Linda_B._Buck
# Linda B. Buck
# /wiki/Barry_Marshall
# Barry Marshall
# /wiki/Robin_Warren
# Robin Warren
# /wiki/Andrew_Fire
# Andrew Fire
# /wiki/Craig_Mello
# Craig Mello
# /wiki/Mario_Capecchi
# Mario Capecchi
# /wiki/Martin_Evans
# Martin Evans
# /wiki/Oliver_Smithies
# Oliver Smithies
# /wiki/Harald_zur_Hausen
# Harald zur Hausen
# /wiki/Fran%C3%A7oise_Barr%C3%A9-Sinoussi
# Françoise Barré-Sinoussi
# /wiki/Luc_Montagnier
# Luc Montagnier
# /wiki/Elizabeth_Blackburn
# Elizabeth Blackburn
# /wiki/Carol_W._Greider
# Carol W. Greider
# /wiki/Jack_W._Szostak
# Jack W. Szostak
# /wiki/Robert_Edwards_(physiologist)
# Robert Edwards
# /wiki/Bruce_Beutler
# Bruce Beutler
# /wiki/Jules_A._Hoffmann
# Jules A. Hoffmann
# /wiki/Ralph_M._Steinman
# Ralph M. Steinman
# /wiki/John_Gurdon
# John B. Gurdon
# /wiki/Shinya_Yamanaka
#  Shinya Yamanaka
# /wiki/James_Rothman
# James E. Rothman
# /wiki/Randy_W._Schekman
# Randy W. Schekman
# /wiki/Thomas_C._S%C3%BCdhof
# Thomas C. Südhof
# /wiki/John_O%27Keefe_(neuroscientist)
# John O'Keefe
# /wiki/May-Britt_Moser
# May-Britt Moser
# /wiki/Edvard_Moser
# Edvard Moser
# /wiki/William_C._Campbell_(scientist)
# William C. Campbell
# /wiki/Satoshi_%C5%8Cmura
# Satoshi Ōmura
# /wiki/Tu_Youyou
# Tu Youyou
# /wiki/Yoshinori_Ohsumi
# Yoshinori Ohsumi
# /wiki/Jeffrey_C._Hall
# Jeffrey C. Hall
# /wiki/Michael_Rosbash
# Michael Rosbash
# /wiki/Michael_W._Young
# Michael W. Young
# /wiki/James_P._Allison
# James P. Allison
# /wiki/Tasuku_Honjo
# Tasuku Honjo
# /wiki/William_Kaelin_Jr.
# William Kaelin Jr.
# /wiki/Peter_J._Ratcliffe
# Peter J. Ratcliffe
# /wiki/Gregg_L._Semenza
# Gregg L. Semenza
# /wiki/Harvey_J._Alter
# Harvey J. Alter
# /wiki/Michael_Houghton_(virologist)
# Michael Houghton
# /wiki/Charles_M._Rice
# Charles M. Rice
# /wiki/David_Julius
# David Julius
# /wiki/Ardem_Patapoutian
# Ardem Patapoutian
# /wiki/Svante_P%C3%A4%C3%A4bo
# Svante Pääbo
# /wiki/Katalin_Karik%C3%B3
# Katalin Karikó
# /wiki/Drew_Weissman
# Drew Weissman
# /wiki/Sully_Prudhomme
# Sully Prudhomme
# /wiki/Theodor_Mommsen
# Theodor Mommsen
# /wiki/Bj%C3%B8rnstjerne_Bj%C3%B8rnson
# Bjørnstjerne Bjørnson
# /wiki/Fr%C3%A9d%C3%A9ric_Mistral
# Frédéric Mistral
# /wiki/Jos%C3%A9_Echegaray
# José Echegaray
# /wiki/Henryk_Sienkiewicz
# Henryk Sienkiewicz
# /wiki/Giosu%C3%A8_Carducci
# Giosuè Carducci
# /wiki/Rudyard_Kipling
# Rudyard Kipling
# /wiki/Rudolf_Christoph_Eucken
# Rudolf Christoph Eucken
# /wiki/Selma_Lagerl%C3%B6f
# Selma Lagerlöf
# /wiki/Paul_Heyse
# Paul Heyse
# /wiki/Maurice_Maeterlinck
# Maurice Maeterlinck
# /wiki/Gerhart_Hauptmann
# Gerhart Hauptmann
# /wiki/Rabindranath_Tagore
# Rabindranath Tagore
# /wiki/Romain_Rolland
# Romain Rolland
# /wiki/Verner_von_Heidenstam
# Verner von Heidenstam
# /wiki/Karl_Adolph_Gjellerup
# Karl Adolph Gjellerup
# /wiki/Henrik_Pontoppidan
# Henrik Pontoppidan
# /wiki/Carl_Spitteler
# Carl Spitteler
# /wiki/Knut_Hamsun
# Knut Hamsun
# /wiki/Anatole_France
# Anatole France
# /wiki/Jacinto_Benavente
# Jacinto Benavente
# /wiki/W._B._Yeats
# W. B. Yeats
# /wiki/W%C5%82adys%C5%82aw_Reymont
# Władysław Reymont
# /wiki/George_Bernard_Shaw
# George Bernard Shaw
# /wiki/Grazia_Deledda
# Grazia Deledda
# /wiki/Henri_Bergson
# Henri Bergson
# /wiki/Sigrid_Undset
# Sigrid Undset
# /wiki/Thomas_Mann
# Thomas Mann
# /wiki/Sinclair_Lewis
# Sinclair Lewis
# /wiki/Erik_Axel_Karlfeldt
# Erik Axel Karlfeldt
# /wiki/John_Galsworthy
# John Galsworthy
# /wiki/Ivan_Bunin
# Ivan Bunin
# /wiki/Luigi_Pirandello
# Luigi Pirandello
# /wiki/Eugene_O%27Neill
# Eugene O'Neill
# /wiki/Roger_Martin_du_Gard
# Roger Martin du Gard
# /wiki/Pearl_S._Buck
# Pearl S. Buck
# /wiki/Frans_Eemil_Sillanp%C3%A4%C3%A4
# Frans Eemil Sillanpää
# /wiki/Johannes_V._Jensen
# Johannes V. Jensen
# /wiki/Gabriela_Mistral
# Gabriela Mistral
# /wiki/Hermann_Hesse
# Hermann Hesse
# /wiki/Andr%C3%A9_Gide
# André Gide
# /wiki/T._S._Eliot
# T. S. Eliot
# /wiki/William_Faulkner
# William Faulkner
# /wiki/Bertrand_Russell
# Bertrand Russell
# /wiki/P%C3%A4r_Lagerkvist
# Pär Lagerkvist
# /wiki/Fran%C3%A7ois_Mauriac
# François Mauriac
# /wiki/Winston_Churchill
# Winston Churchill
# /wiki/Ernest_Hemingway
# Ernest Hemingway
# /wiki/Halld%C3%B3r_Laxness
# Halldór Laxness
# /wiki/Juan_Ram%C3%B3n_Jim%C3%A9nez
# Juan Ramón Jiménez
# /wiki/Albert_Camus
# Albert Camus
# /wiki/Salvatore_Quasimodo
# Salvatore Quasimodo
# /wiki/Saint-John_Perse
# Saint-John Perse
# /wiki/Ivo_Andri%C4%87
# Ivo Andrić
# /wiki/John_Steinbeck
# John Steinbeck
# /wiki/Giorgos_Seferis
# Giorgos Seferis
# /wiki/Mikhail_Sholokhov
# Mikhail Sholokhov
# /wiki/Shmuel_Yosef_Agnon
# Shmuel Yosef Agnon
# /wiki/Nelly_Sachs
# Nelly Sachs
# /wiki/Miguel_%C3%81ngel_Asturias
# Miguel Ángel Asturias
# /wiki/Yasunari_Kawabata
# Yasunari Kawabata
# /wiki/Samuel_Beckett
# Samuel Beckett
# /wiki/Aleksandr_Solzhenitsyn
# Aleksandr Solzhenitsyn
# /wiki/Pablo_Neruda
# Pablo Neruda
# /wiki/Heinrich_B%C3%B6ll
# Heinrich Böll
# /wiki/Patrick_White
# Patrick White
# /wiki/Eyvind_Johnson
# Eyvind Johnson
# /wiki/Harry_Martinson
# Harry Martinson
# /wiki/Eugenio_Montale
# Eugenio Montale
# /wiki/Saul_Bellow
# Saul Bellow
# /wiki/Vicente_Aleixandre
# Vicente Aleixandre
# /wiki/Isaac_Bashevis_Singer
# Isaac Bashevis Singer
# /wiki/Odysseas_Elytis
# Odysseas Elytis
# /wiki/Czes%C5%82aw_Mi%C5%82osz
# Czesław Miłosz
# /wiki/Elias_Canetti
# Elias Canetti
# /wiki/Gabriel_Garc%C3%ADa_M%C3%A1rquez
# Gabriel García Márquez
# /wiki/William_Golding
# William Golding
# /wiki/Jaroslav_Seifert
# Jaroslav Seifert
# /wiki/Claude_Simon
# Claude Simon
# /wiki/Wole_Soyinka
# Wole Soyinka
# /wiki/Joseph_Brodsky
# Joseph Brodsky
# /wiki/Naguib_Mahfouz
# Naguib Mahfouz
# /wiki/Camilo_Jos%C3%A9_Cela
# Camilo José Cela
# /wiki/Octavio_Paz
# Octavio Paz
# /wiki/Nadine_Gordimer
# Nadine Gordimer
# /wiki/Derek_Walcott
# Derek Walcott
# /wiki/Toni_Morrison
# Toni Morrison
# /wiki/Kenzabur%C5%8D_%C5%8Ce
# Kenzaburō Ōe
# /wiki/Seamus_Heaney
# Seamus Heaney
# /wiki/Wis%C5%82awa_Szymborska
# Wisława Szymborska
# /wiki/Dario_Fo
# Dario Fo
# /wiki/Jos%C3%A9_Saramago
# José Saramago
# /wiki/G%C3%BCnter_Grass
# Günter Grass
# /wiki/Gao_Xingjian
# Gao Xingjian
# /wiki/V._S._Naipaul
# V. S. Naipaul
# /wiki/Imre_Kert%C3%A9sz
# Imre Kertész
# /wiki/J._M._Coetzee
# J. M. Coetzee
# /wiki/Elfriede_Jelinek
# Elfriede Jelinek
# /wiki/Harold_Pinter
# Harold Pinter
# /wiki/Orhan_Pamuk
# Orhan Pamuk
# /wiki/Doris_Lessing
# Doris Lessing
# /wiki/J._M._G._Le_Cl%C3%A9zio
# J. M. G. Le Clézio
# /wiki/Herta_M%C3%BCller
# Herta Müller
# /wiki/Mario_Vargas_Llosa
# Mario Vargas Llosa
# /wiki/Tomas_Transtr%C3%B6mer
# Tomas Tranströmer
# /wiki/Mo_Yan
# Mo Yan
# /wiki/Alice_Munro
# Alice Munro
# /wiki/Patrick_Modiano
# Patrick Modiano
# /wiki/Svetlana_Alexievich
# Svetlana Alexievich
# /wiki/Bob_Dylan
# Bob Dylan
# /wiki/Kazuo_Ishiguro
# Kazuo Ishiguro
# /wiki/Peter_Handke
# Peter Handke
# /wiki/Louise_Gl%C3%BCck
# Louise Glück
# /wiki/Abdulrazak_Gurnah
# Abdulrazak Gurnah
# /wiki/Annie_Ernaux
# Annie Ernaux
# /wiki/Jon_Fosse
# Jon Fosse
# /wiki/Henry_Dunant
# Henry Dunant
# /wiki/Fr%C3%A9d%C3%A9ric_Passy
# Frédéric Passy
# /wiki/%C3%89lie_Ducommun
# Élie Ducommun
# /wiki/Charles_Albert_Gobat
# Charles Albert Gobat
# /wiki/Randal_Cremer
# Randal Cremer
# /wiki/Institut_de_Droit_International
# Institut de Droit International
# /wiki/Bertha_von_Suttner
# Bertha von Suttner
# /wiki/Theodore_Roosevelt
# Theodore Roosevelt
# /wiki/Ernesto_Teodoro_Moneta
# Ernesto Teodoro Moneta
# /wiki/Louis_Renault_(jurist)
# Louis Renault
# /wiki/Klas_Pontus_Arnoldson
# Klas Pontus Arnoldson
# /wiki/Fredrik_Bajer
# Fredrik Bajer
# /wiki/Auguste_Beernaert
# Auguste Beernaert
# /wiki/Paul_Henri_Balluet_d%27Estournelles_de_Constant
# Paul Henri Balluet d'Estournelles de Constant
# /wiki/International_Peace_Bureau
# International Peace Bureau
# /wiki/Tobias_Asser
# Tobias Asser
# /wiki/Alfred_Hermann_Fried
# Alfred Hermann Fried
# /wiki/Elihu_Root
# Elihu Root
# /wiki/Henri_La_Fontaine
# Henri La Fontaine
# /wiki/International_Committee_of_the_Red_Cross
# International Committee of the Red Cross
# /wiki/Woodrow_Wilson
# Woodrow Wilson
# /wiki/L%C3%A9on_Bourgeois
# Léon Bourgeois
# /wiki/Hjalmar_Branting
# Hjalmar Branting
# /wiki/Christian_Lous_Lange
# Christian Lous Lange
# /wiki/Fridtjof_Nansen
# Fridtjof Nansen
# /wiki/Austen_Chamberlain
# Austen Chamberlain
# /wiki/Charles_G._Dawes
# Charles G. Dawes
# /wiki/Aristide_Briand
# Aristide Briand
# /wiki/Gustav_Stresemann
# Gustav Stresemann
# /wiki/Ferdinand_Buisson
# Ferdinand Buisson
# /wiki/Ludwig_Quidde
# Ludwig Quidde
# /wiki/Frank_B._Kellogg
# Frank B. Kellogg
# /wiki/Nathan_S%C3%B6derblom
# Nathan Söderblom
# /wiki/Jane_Addams
# Jane Addams
# /wiki/Nicholas_Murray_Butler
# Nicholas Murray Butler
# /wiki/Norman_Angell
# Norman Angell
# /wiki/Arthur_Henderson
# Arthur Henderson
# /wiki/Carl_von_Ossietzky
# Carl von Ossietzky
# /wiki/Carlos_Saavedra_Lamas
# Carlos Saavedra Lamas
# /wiki/Robert_Cecil,_1st_Viscount_Cecil_of_Chelwood
# Robert Cecil, 1st Viscount Cecil of Chelwood
# /wiki/Nansen_International_Office_for_Refugees
# Nansen International Office for Refugees
# /wiki/International_Committee_of_the_Red_Cross
# International Committee of the Red Cross
# /wiki/Cordell_Hull
# Cordell Hull
# /wiki/Emily_Greene_Balch
# Emily Greene Balch
# /wiki/John_Mott
# John Mott
# /wiki/Quaker_Peace_and_Social_Witness
# Friends Service Council
# /wiki/American_Friends_Service_Committee
# American Friends Service Committee
# /wiki/John_Boyd_Orr
# John Boyd Orr
# /wiki/Ralph_Bunche
# Ralph Bunche
# /wiki/L%C3%A9on_Jouhaux
# Léon Jouhaux
# /wiki/Albert_Schweitzer
# Albert Schweitzer
# /wiki/George_Marshall
# George Marshall
# /wiki/United_Nations_High_Commissioner_for_Refugees
# United Nations High Commissioner for Refugees
# /wiki/Lester_B._Pearson
# Lester B. Pearson
# /wiki/Dominique_Pire
# Dominique Pire
# /wiki/Philip_Noel-Baker
# Philip Noel-Baker
# /wiki/Albert_Lutuli
# Albert Lutuli
# /wiki/Dag_Hammarskj%C3%B6ld
# Dag Hammarskjöld
# /wiki/Linus_Pauling
# Linus Pauling
# /wiki/International_Committee_of_the_Red_Cross
# International Committee of the Red Cross
# /wiki/International_Federation_of_Red_Cross_and_Red_Crescent_Societies
# League of Red Cross societies
# /wiki/Martin_Luther_King_Jr.
# Martin Luther King Jr.
# /wiki/UNICEF
# United Nations International Children's Emergency Fund
# /wiki/Ren%C3%A9_Cassin
# René Cassin
# /wiki/International_Labour_Organization
# International Labour Organization
# /wiki/Norman_Borlaug
# Norman Borlaug
# /wiki/Willy_Brandt
# Willy Brandt
# /wiki/Henry_Kissinger
# Henry Kissinger
# /wiki/Se%C3%A1n_MacBride
# Seán MacBride
# /wiki/Eisaku_Sat%C5%8D
# Eisaku Satō
# /wiki/Andrei_Sakharov
# Andrei Sakharov
# /wiki/Betty_Williams_(peace_activist)
# Betty Williams
# /wiki/Mairead_Maguire
# Mairead Maguire
# /wiki/Amnesty_International
# Amnesty International
# /wiki/Anwar_Sadat
# Anwar Sadat
# /wiki/Menachem_Begin
# Menachem Begin
# /wiki/Mother_Teresa
# Mother Teresa
# /wiki/Adolfo_P%C3%A9rez_Esquivel
# Adolfo Pérez Esquivel
# /wiki/United_Nations_High_Commissioner_for_Refugees
# United Nations High Commissioner for Refugees
# /wiki/Alva_Myrdal
# Alva Myrdal
# /wiki/Alfonso_Garc%C3%ADa_Robles
# Alfonso García Robles
# /wiki/Lech_Wa%C5%82%C4%99sa
# Lech Wałęsa
# /wiki/Desmond_Tutu
# Desmond Tutu
# /wiki/International_Physicians_for_the_Prevention_of_Nuclear_War
# International Physicians for the Prevention of Nuclear War
# /wiki/Elie_Wiesel
# Elie Wiesel
# /wiki/%C3%93scar_Arias
# Óscar Arias
# /wiki/United_Nations_peacekeeping
# United Nations peacekeeping forces
# /wiki/14th_Dalai_Lama
# Tenzin Gyatso (The 14th Dalai Lama)
# /wiki/Mikhail_Gorbachev
# Mikhail Gorbachev
# /wiki/Aung_San_Suu_Kyi
# Aung San Suu Kyi
# /wiki/Rigoberta_Mench%C3%BA
# Rigoberta Menchú
# /wiki/Nelson_Mandela
# Nelson Mandela
# /wiki/F._W._de_Klerk
# F. W. de Klerk
# /wiki/Yasser_Arafat
# Yasser Arafat
# /wiki/Shimon_Peres
# Shimon Peres
# /wiki/Yitzhak_Rabin
# Yitzhak Rabin
# /wiki/Joseph_Rotblat
# Joseph Rotblat
# /wiki/Pugwash_Conferences_on_Science_and_World_Affairs
# Pugwash Conferences on Science and World Affairs
# /wiki/Carlos_Filipe_Ximenes_Belo
# Carlos Filipe Ximenes Belo
# /wiki/Jos%C3%A9_Ramos-Horta
# José Ramos-Horta
# /wiki/International_Campaign_to_Ban_Landmines
# International Campaign to Ban Landmines
# /wiki/Jody_Williams
# Jody Williams
# /wiki/John_Hume
# John Hume
# /wiki/David_Trimble
# David Trimble
# /wiki/M%C3%A9decins_Sans_Fronti%C3%A8res
# Médecins Sans Frontières
# /wiki/Kim_Dae-jung
# Kim Dae-jung
# /wiki/United_Nations
# United Nations
# /wiki/Kofi_Annan
# Kofi Annan
# /wiki/Jimmy_Carter
# Jimmy Carter
# /wiki/Shirin_Ebadi
# Shirin Ebadi
# /wiki/Wangari_Maathai
# Wangari Maathai
# /wiki/International_Atomic_Energy_Agency
# International Atomic Energy Agency
# /wiki/Mohamed_ElBaradei
# Mohamed ElBaradei
# /wiki/Muhammad_Yunus
# Muhammad Yunus
# /wiki/Grameen_Bank
# Grameen Bank
# /wiki/Intergovernmental_Panel_on_Climate_Change
# Intergovernmental Panel on Climate Change
# /wiki/Al_Gore
# Al Gore
# /wiki/Martti_Ahtisaari
# Martti Ahtisaari
# /wiki/Ellen_Johnson_Sirleaf
# Ellen Johnson Sirleaf
# /wiki/Leymah_Gbowee
# Leymah Gbowee
# /wiki/Tawakel_Karman
# Tawakel Karman
# /wiki/European_Union
# European Union
# /wiki/Organisation_for_the_Prohibition_of_Chemical_Weapons
# Organisation for the Prohibition of Chemical Weapons
# /wiki/Kailash_Satyarthi
# Kailash Satyarthi
# /wiki/Malala_Yousafzai
# Malala Yousafzai
# /wiki/Tunisian_National_Dialogue_Quartet
# Tunisian National Dialogue Quartet
# /wiki/Juan_Manuel_Santos
# Juan Manuel Santos
# /wiki/International_Campaign_to_Abolish_Nuclear_Weapons
# International Campaign to Abolish Nuclear Weapons
# /wiki/Denis_Mukwege
# Denis Mukwege
# /wiki/Nadia_Murad
# Nadia Murad
# /wiki/Abiy_Ahmed
# Abiy Ahmed
# /wiki/World_Food_Programme
# World Food Programme
# /wiki/Maria_Ressa
# Maria Ressa
# /wiki/Dmitry_Muratov
# Dmitry Muratov
# /wiki/Ales_Bialiatski
# Ales Bialiatski
# /wiki/Memorial_(society)
# Memorial
# /wiki/Center_for_Civil_Liberties_(human_rights_organization)
# Centre for Civil Liberties
# /wiki/Narges_Mohammadi
# Narges Mohammadi
# /wiki/Ragnar_Frisch
# Ragnar Frisch
# /wiki/Jan_Tinbergen
# Jan Tinbergen
# /wiki/Paul_Samuelson
# Paul Samuelson
# /wiki/Simon_Kuznets
# Simon Kuznets
# /wiki/John_Hicks
# John Hicks
# /wiki/Kenneth_Arrow
# Kenneth Arrow
# /wiki/Wassily_Leontief
# Wassily Leontief
# /wiki/Gunnar_Myrdal
# Gunnar Myrdal
# /wiki/Friedrich_Hayek
# Friedrich Hayek
# /wiki/Leonid_Kantorovich
# Leonid Kantorovich
# /wiki/Tjalling_Koopmans
# Tjalling Koopmans
# /wiki/Milton_Friedman
# Milton Friedman
# /wiki/Bertil_Ohlin
# Bertil Ohlin
# /wiki/James_Meade
# James Meade
# /wiki/Herbert_A._Simon
# Herbert A. Simon
# /wiki/Theodore_Schultz
# Theodore Schultz
# /wiki/W._Arthur_Lewis
# W. Arthur Lewis
# /wiki/Lawrence_Klein
# Lawrence Klein
# /wiki/James_Tobin
# James Tobin
# /wiki/George_Stigler
# George Stigler
# /wiki/G%C3%A9rard_Debreu
# Gérard Debreu
# /wiki/Richard_Stone
# Richard Stone
# /wiki/Franco_Modigliani
# Franco Modigliani
# /wiki/James_M._Buchanan
# James M. Buchanan
# /wiki/Robert_Solow
# Robert Solow
# /wiki/Maurice_Allais
# Maurice Allais
# /wiki/Trygve_Haavelmo
# Trygve Haavelmo
# /wiki/Harry_Markowitz
# Harry Markowitz
# /wiki/Merton_Miller
# Merton Miller
# /wiki/William_F._Sharpe
# William F. Sharpe
# /wiki/Ronald_Coase
# Ronald Coase
# /wiki/Gary_Becker
# Gary Becker
# /wiki/Robert_Fogel
# Robert Fogel
# /wiki/Douglass_North
# Douglass North
# /wiki/John_Harsanyi
# John Harsanyi
# /wiki/John_Forbes_Nash_Jr.
# John Forbes Nash Jr.
# /wiki/Reinhard_Selten
# Reinhard Selten
# /wiki/Robert_Lucas_Jr.
# Robert Lucas Jr.
# /wiki/James_Mirrlees
# James Mirrlees
# /wiki/William_Vickrey
# William Vickrey
# /wiki/Robert_C._Merton
# Robert C. Merton
# /wiki/Myron_Scholes
# Myron Scholes
# /wiki/Amartya_Sen
# Amartya Sen
# /wiki/Robert_Mundell
# Robert Mundell
# /wiki/James_Heckman
# James Heckman
# /wiki/Daniel_McFadden
# Daniel McFadden
# /wiki/George_Akerlof
# George Akerlof
# /wiki/Michael_Spence
# Michael Spence
# /wiki/Joseph_Stiglitz
# Joseph Stiglitz
# /wiki/Daniel_Kahneman
# Daniel Kahneman
# /wiki/Vernon_L._Smith
# Vernon L. Smith
# /wiki/Robert_F._Engle
# Robert F. Engle
# /wiki/Clive_Granger
# Clive Granger
# /wiki/Finn_E._Kydland
# Finn E. Kydland
# /wiki/Edward_C._Prescott
# Edward C. Prescott
# /wiki/Robert_Aumann
# Robert Aumann
# /wiki/Thomas_Schelling
# Thomas Schelling
# /wiki/Edmund_Phelps
# Edmund Phelps
# /wiki/Leonid_Hurwicz
# Leonid Hurwicz
# /wiki/Eric_Maskin
# Eric Maskin
# /wiki/Roger_Myerson
# Roger Myerson
# /wiki/Paul_Krugman
# Paul Krugman
# /wiki/Elinor_Ostrom
# Elinor Ostrom
# /wiki/Oliver_E._Williamson
# Oliver E. Williamson
# /wiki/Peter_Diamond
# Peter A. Diamond
# /wiki/Thomas_J._Sargent
# Thomas J. Sargent
# /wiki/Christopher_A._Sims
# Christopher A. Sims
# /wiki/Alvin_E._Roth
# Alvin E. Roth
# /wiki/Lloyd_Shapley
# Lloyd S. Shapley
# /wiki/Eugene_Fama
# Eugene F. Fama
# /wiki/Lars_Peter_Hansen
# Lars Peter Hansen
# /wiki/Robert_Shiller
# Robert J. Shiller
# /wiki/Jean_Tirole
# Jean Tirole
# /wiki/Angus_Deaton
# Angus Deaton
# /wiki/Oliver_Hart_(economist)
# Oliver Hart
# /wiki/Bengt_R._Holmstr%C3%B6m
# Bengt R. Holmström
# /wiki/Richard_Thaler
# Richard Thaler
# /wiki/William_Nordhaus
# William Nordhaus
# /wiki/Paul_Romer
# Paul Romer
# /wiki/Abhijit_Banerjee
# Abhijit Banerjee
# /wiki/Esther_Duflo
# Esther Duflo
# /wiki/Michael_Kremer
# Michael Kremer
# /wiki/Paul_Milgrom
# Paul Milgrom
# /wiki/Robert_B._Wilson
# Robert B. Wilson
# /wiki/David_Card
# David Card
# /wiki/Joshua_Angrist
# Joshua Angrist
# /wiki/Guido_Imbens
# Guido Imbens
# /wiki/Ben_Bernanke
# Ben Bernanke
# /wiki/Douglas_Diamond
# Douglas Diamond
# /wiki/Philip_H._Dybvig
# Philip H. Dybvig
# /wiki/Claudia_Goldin
# Claudia Goldin

# %%
special = BeautifulSoup(look_up.content,"html.parser")

# %%
specyfic = pd.read_html("https://en.m.wikipedia.org" + look["href"])[0]#, match="Nationality")

print(specyfic.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Wilhelm Röntgen    15 non-null     object
#  1   Wilhelm Röntgen.1  15 non-null     object
# dtypes: object(2)
# memory usage: 388.0+ bytes
# None

# %%
specyfic[dict["Physics"][0] + ".1"][3]
# Out:
# 'Prussian (1845–1848) Stateless (1848–1888) German (1888–1923)[1]'

# %%
for i in range(0,len(dict["Physics"])):
    specyfic.loc[specyfic[dict["Physics"][i]] == "Nationality"][dict["Physics"][i]+".1"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Hendrik Lorentz'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /Users/rodolforincon/Documents/quieroelipad/iwantheipad/note.ipynb Cell 19 line 2
#       <a href='vscode-notebook-cell:/Users/rodolforincon/Documents/quieroelipad/iwantheipad/note.ipynb#X26sZmlsZQ%3D%3D?line=0'>1</a> for i in range(0,len(dict["Physics"])):
# ----> <a href='vscode-notebook-cell:/Users/rodolforincon/Documents/quieroelipad/iwantheipad/note.ipynb#X26sZmlsZQ%3D%3D?line=1'>2</a>     specyfic.loc[specyfic[dict["Physics"][i]] == "Nationality"][dict["Physics"][i]+".1"]
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/indexes/base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'Hendrik Lorentz'
